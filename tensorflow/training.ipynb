# %% [markdown]
# ### Actual Training for Tensorflow
# #### Should work for pyTorch as well with minor modifications.
# Intended to be a drop in for Kaggle.

# %%
from model import KerasModel
from train_utils import *
from tqdm.notebook import tqdm
# Out:
# 2023-09-06 05:36:07.915928: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-06 05:36:07.943878: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-06 05:36:07.944799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-06 05:36:08.733238: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#! Defining training parameters
games = 100 #number of games per epoch
epochs = 500
svae_every = 50
per_epoch_training_steps = 10
config = "base_config"
training_set = "/home/juggernautjha/Desktop/trexquant/rnn_testing/data/250k_complement.txt"
checkpoint_saving = "tensorflow_model"

# %%
m = KerasModel(config=config)
trainer = Train_on_Batch(training_set, m, games)
progbar = tqdm(range(epochs))
for epoch in progbar:
    trainer.train_one_batch(per_epoch_training_steps)
    trainer.reset()
    if (epoch+1)%save_every == 0:
        m.save_weights(f"{checkpoint_saving}_{epoch}")
# Out:
# 2023-09-06 05:41:48.709860: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-06 05:41:48.711645: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
#   0%|          | 0/500 [00:00<?, ?it/s]
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# doctrinally
# _______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# transcriptively
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# steiner
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# porcini
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 7, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 7, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 7, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 7, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 7, 27, 27]
# overthought
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# untreatably
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 7, 27]
# compage
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 27]
# unstupidly
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# lubricatory
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# oustee
# _________________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# schizogenetically
# _____
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 11]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11]
# crank
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# banshies
# _____________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# monocephalous
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [11, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [11, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [11, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [11, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [11, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [11, 27, 27, 27, 27, 27, 27]
# knoweth
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# azines
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27]
# miranda
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27]
# joinder
# _____________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 4]
# preindisposed
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# locution
# ______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4, 27]
# endopolyploidy
# _______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# nonemotionalism
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# armata
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# belatedness
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# estamp
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4, 27, 4]
# nonbranded
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# primate
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 4, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 4, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27]
# condom
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# ironize
# ____________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# undisorderly
# _____
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# jawab
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# paxwaxes
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 7, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 7, 27]
# synechology
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 4, 27, 27, 27]
# spasmodism
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 11, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 11, 27, 27]
# stocker
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# perter
# _________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# lollypops
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 4, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 4, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27]
# weirdo
# ______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# basidiosporous
# _____
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 4, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 4, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 4, 27, 27]
# medic
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# comvia
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# reinitiate
# _____
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# major
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# patted
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4]
# coward
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# smircher
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 4, 27, 27, 27, 27, 27]
# glanderous
# _____
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27]
# focal
# ______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 7, 27, 27, 27, 27, 27, 27, 27]
# phenylglycolic
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27]
# galibi
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 7, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 7, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 7, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 7, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 7, 27, 27, 27]
# slingman
# _____________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 27, 27, 4, 27, 27, 27, 27]
# gerrymanderer
# _________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# encircler
# _______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# disenthronement
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27]
# phoneys
# ___________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 4]
# teeterboard
# ______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# hippocentauric
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 11, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 11, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 11, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 11, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 11, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 11, 27, 27, 27]
# lockups
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# philippize
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# inherits
# _________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [4, 27, 27, 27, 27, 27, 27, 27, 27]
# discanter
# _________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 7, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 7, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 7, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 7, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 7, 27, 27, 27, 27, 27, 27]
# rigoletto
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 4]
# clavered
# _________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27]
# jacobsohn
# ________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27]
# recarbon
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# copromisor
# ______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27]
# lawtun
# __________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# unpriority
# ____________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# acanthopteri
# ___
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27]
# tat
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 4, 27, 27, 27]
# burdies
# ____________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# preallotment
# ______________
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 6
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 5
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 3
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 2
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# Tries remaining : 1
# g
# ['k', 'd', 'g']
# [27, 27, 27, 27, 27, 4, 27, 27, 27, 4, 27, 27, 27, 27]
# unpardonedness
# _______
# Now Play
# Tries remaining : 6
# d
# ['d']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 5
# k
# ['k', 'd']
# [27, 27, 27, 27, 27, 27, 27]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 7]
# Tries remaining : 4
# g
# ['k', 'd', 'g']
# [7, 27, 27, 27, 27, 27, 7]
# Tries remaining : 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 progbar = tqdm(range(epochs))
#       4 for epoch in progbar:
# ----> 5     trainer.train_one_batch(per_epoch_training_steps)
#       6     trainer.reset()
#       7     if (epoch+1)%save_every == 0:
#
# File ~/Desktop/trexquant/rnn_testing/tensorflow/train_utils.py:199, in Train_on_Batch.train_one_batch(self, epochs)
#     197 word =self.pick_random_word()
#     198 player = Trainer(word, self.guessing_model, self.tries)
# --> 199 player.play()
#     200 for key in self.batch_memory:
#     201     self.batch_memory[key] += player.training_set[key]
#
# File ~/Desktop/trexquant/rnn_testing/tensorflow/train_utils.py:145, in Trainer.play(self)
#     142 while len(self.remaining) > 0 and self.tries_remain > 0:
#     143     if (self.verbosity): print(f"Tries remaining : {self.tries_remain}")
# --> 145     probab_vector = self.get_guess_vector()
#     146     #! greedy
#     147     char_idx = np.argmax(probab_vector)
#
# File ~/Desktop/trexquant/rnn_testing/tensorflow/train_utils.py:129, in Trainer.get_guess_vector(self)
#     127 game_state = np.vstack(self.training_set['game_state'][-1:]).astype(float)
#     128 guessed = np.vstack(self.training_set['guessed_one_hot'][-1:]).astype(float)
# --> 129 probab_vector = self.guessing_model(game_state, guessed)
#     130 return probab_vector
#
# File ~/Desktop/trexquant/rnn_testing/tensorflow/model.py:104, in KerasModel.__call__(self, game_state_encoding, guessed_state_encoding)
#     103 def __call__(self, game_state_encoding, guessed_state_encoding):
# --> 104     return self.guessing_model.predict([game_state_encoding, guessed_state_encoding], verbose='false').flatten()
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/keras/src/engine/training.py:2521, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2512     except ValueError:
#    2513         warnings.warn(
#    2514             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2515             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2518             stacklevel=2,
#    2519         )
# -> 2521 data_handler = data_adapter.get_data_handler(
#    2522     x=x,
#    2523     batch_size=batch_size,
#    2524     steps_per_epoch=steps,
#    2525     initial_epoch=0,
#    2526     epochs=1,
#    2527     max_queue_size=max_queue_size,
#    2528     workers=workers,
#    2529     use_multiprocessing=use_multiprocessing,
#    2530     model=self,
#    2531     steps_per_execution=self._steps_per_execution,
#    2532 )
#    2534 # Container that configures and calls `tf.keras.Callback`s.
#    2535 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1678, in get_data_handler(*args, **kwargs)
#    1676         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1677     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1678 return DataHandler(*args, **kwargs)
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1307, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1304 self._step_increment = self._steps_per_execution.numpy().item() - 1
#    1305 self._insufficient_data = False
# -> 1307 self._configure_dataset_and_inferred_steps(
#    1308     strategy, x, steps_per_epoch, class_weight, distribute
#    1309 )
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1326, in DataHandler._configure_dataset_and_inferred_steps(***failed resolving arguments***)
#    1324     dataset = strategy.experimental_distribute_dataset(dataset)
#    1325 self._dataset = dataset
# -> 1326 self._validate_data_handler()
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1494, in DataHandler._validate_data_handler(self)
#    1491 def _validate_data_handler(self):
#    1492     # TODO(b/152094471): Support this with DistIter.get_next_as_optional.
#    1493     if (
# -> 1494         self._steps_per_execution.numpy().item() > 1
#    1495         and self._inferred_steps is None
#    1496     ):
#    1497         raise ValueError(
#    1498             "Could not infer the size of the data. With "
#    1499             "`steps_per_execution > 1`, you must specify the number of "
#    1500             "steps to run."
#    1501         )
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:688, in BaseResourceVariable.numpy(self)
#     686 def numpy(self):
#     687   if context.executing_eagerly():
# --> 688     return self.read_value().numpy()
#     689   raise NotImplementedError(
#     690       "numpy() is only available when eager execution is enabled.")
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:815, in BaseResourceVariable.read_value(self)
#     806 """Constructs an op which reads the value of this variable.
#     807
#     808 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     812   The value of the variable.
#     813 """
#     814 with ops.name_scope("Read"):
# --> 815   value = self._read_variable_op()
#     816 # Return an identity so it can get placed on whatever device the context
#     817 # specifies instead of the device where the variable is.
#     818 return array_ops.identity(value)
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:794, in BaseResourceVariable._read_variable_op(self, no_copy)
#     792       result = read_and_set_handle(no_copy)
#     793 else:
# --> 794   result = read_and_set_handle(no_copy)
#     796 if not context.executing_eagerly():
#     797   # Note that if a control flow context is active the input of the read op
#     798   # might not actually be the handle. This line bypasses it.
#     799   record.record_operation(
#     800       "ReadVariableOp", [result], [self.handle],
#     801       backward_function=lambda x: [x],
#     802       forward_function=lambda x: [x])
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:784, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     782 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     783   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 784 result = gen_resource_variable_ops.read_variable_op(
#     785     self.handle, self._dtype)
#     786 _maybe_set_handle_data(self._dtype, self.handle, result)
#     787 return result
#
# File ~/Desktop/trexquant/tre/lib/python3.11/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:525, in read_variable_op(resource, dtype, name)
#     523 if tld.is_eager:
#     524   try:
# --> 525     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     526       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     527     return _result
#     528   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
